# %% [markdown]
# # Taxi con DQN

# %%
import gym
from agent import TaxiAgent
from model import DQN

# %% [markdown]
# Seleccionamos el entorno

# %%
env = gym.make("Taxi-v3").env

# %%
agent = TaxiAgent(env=env, model=DQN,device='cpu')
agent.preparar()
agent.mostrar_info_cuda()
agent.mostrar_datos_clase()
# Out:
# GeForce GTX 1060 6GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# Free:      0.0 GB
# id: taxiDQN_8_2_3_1
# gamma: 0.99
# optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# loss: L1Loss()
# device: cpu
# model: DQN(
#   (emb): Embedding(500, 4)
#   (l1): Linear(in_features=4, out_features=50, bias=True)
#   (l2): Linear(in_features=50, out_features=50, bias=True)
#   (l3): Linear(in_features=50, out_features=6, bias=True)
# )
# modeloObjetivo: DQN(
#   (emb): Embedding(500, 4)
#   (l1): Linear(in_features=4, out_features=50, bias=True)
#   (l2): Linear(in_features=50, out_features=50, bias=True)
#   (l3): Linear(in_features=50, out_features=6, bias=True)
# )
# env: <TaxiEnv<Taxi-v3>>
# episodios_exitosos: 0

# %% [markdown]
# ### Entrenamos el agente

# %%
agent.entrenar_por_lotes(num_episodes=50000,grafica=True)
# Out:
# Episodio: 29673
# Ratio de exito: 266 / 29673

# %% [markdown]
# ### Probamos el agente
# Objetivo acabar en Azul

# %% [markdown]
# ### TEST

# %%
agent.jugar(sleep= 0.1)
# Out:
# No funciona

# %%
"""
    Graficar los resultados del entrenamiento.
"""
import matplotlib.pyplot as plt

lines = []
fig = plt.figure(1, figsize=(15, 7))
plt.clf()
ax1 = fig.add_subplot(111)

plt.title('Training...')
ax1.set_xlabel('Episode')
ax1.set_ylabel('Duration & Rewards')
# Out:
# Text(0, 0.5, 'Duration & Rewards')
